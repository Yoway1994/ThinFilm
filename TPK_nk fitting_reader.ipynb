# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#os.chdir('./c_f')

# %%
wl = []
top_oc = []
top_sin = []
top_sio2 = []
ito = []
bot_sio2 = []
bot_sin = []
sio2_n = []
sio2_k = []
sin_n = []
sin_k = []
ito_n = []
ito_k = []

for csv in os.listdir():
    file = pd.read_csv('{}'.format(csv), index_col = 0)
    w = int(file.columns.values[0])
    ta = file.values[0][0]
    tsin = file.values[1][0]
    tsio2 = file.values[2][0]
    tito = file.values[3][0]
    bsio2 = file.values[4][0]
    bsin = file.values[5][0]
    sio2n = file.values[6][0]
    sio2k = file.values[7][0]
    sinn = file.values[8][0]
    sink = file.values[9][0]
    iton = file.values[10][0]
    itok = file.values[11][0]
    wl.append(w)
    top_oc.append(ta)
    top_sin.append(tsin)
    top_sio2.append(tsio2)
    ito.append(tito)
    bot_sio2.append(bsio2)
    bot_sin.append(bsin)
    sio2_n.append(sio2n)
    sio2_k.append(sio2k)
    sin_n.append(sinn)
    sin_k.append(sink)
    ito_n.append(iton)
    ito_k.append(itok)

# %%
plt.plot(wl, top_oc)
plt.plot(wl, np.ones(np.size(wl))*np.mean(top_oc))
plt.xticks(wl, fontsize=5)
print(np.mean(top_oc))
plt.show()
# Out:
# 1774.3730332154641

# %%
plt.plot(wl, top_sin)
plt.plot(wl, np.ones(np.size(wl))*np.mean(top_sin))
plt.show()

# %%
plt.plot(wl, top_sio2)
plt.plot(wl, np.ones(np.size(wl))*np.mean(top_sio2))
plt.show()

# %%
plt.plot(wl, ito)
plt.plot(wl, np.ones(np.size(wl))*np.mean(ito))
plt.show()

# %%
plt.plot(wl, bot_sio2)
plt.plot(wl, np.ones(np.size(wl))*np.mean(bot_sio2))
plt.show()

# %%
plt.plot(wl, bot_sin)
plt.plot(wl, np.ones(np.size(wl))*np.mean(bot_sin))
plt.show()

# %%
plt.plot(wl, sio2_n)
plt.show()

# %%
plt.plot(wl, sio2_k)
plt.show()

# %%
plt.plot(wl, sin_n)
plt.show()

# %%
plt.plot(wl, sin_k)
plt.show()

# %%
plt.plot(wl, ito_n)
plt.show()

# %%
plt.plot(wl, ito_k)
plt.show()
