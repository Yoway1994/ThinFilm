# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
eds = pd.read_csv('./TPK_EDS/linescan.csv', index_col = 0)[178:470]
pos = eds['Position [µm]'].values
mss = eds['MSS'].values
pt = eds['Pt'].values
c = eds['C'].values
si = eds['Si'].values
s = eds['S'].values
o = eds['O'].values
n = eds['N'].values
In = eds['In'].values

# %%
plt.figure(num=None, figsize=(3, 12), dpi=80)
plt.plot(o, pos, '-b', label = 'O')
plt.plot(n, pos, '-r', label = 'N')
plt.plot(si, pos, '-k', label = 'Si')
plt.plot(In, pos, '-g', label = 'In')
plt.gca().invert_yaxis()
plt.legend(loc = 'best')
#plt.savefig('test.png')
plt.show()
