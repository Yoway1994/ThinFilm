# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
wl = [425, 475, 525, 575, 625, 675]
top_oc = [1661.2, 1880.2, 1906.0, 1900.0, 1961.7, 1988.1]
top_SiN = [9.88, 10.81, 8.66, 9.73, 8.21, 8.35]
top_SiO2 = [45.2, 54.9, 44.9, 57.9, 49.2, 46.3]
ITO = [24.5, 24.2, 25.3, 25.8, 24.3, 22.8]
bot_SiO2 = [56.7, 49.1, 59.4, 57.0, 49.6, 50.3]
bot_SiN = [11.9, 12, 8.2, 11.4, 9.2, 9.5]
SiO2_n = [1.42, 1.4, 1.45, 1.4, 1.44, 1.48]
SiN_n = [2.04, 2, 2.43, 1.95, 1.98, 2.14]
ITO_n = [1.87, 1.84, 1.8, 1.74, 1.89, 1.8]

# %%
plt.plot(wl, top_oc, label = 'top_oc')
plt.legend()
plt.show()
plt.plot(wl, top_SiN, label = 'top_SiN')
plt.plot(wl, bot_SiN, label = 'bot_SiN')
plt.legend()
plt.show()
plt.plot(wl, SiN_n, label = 'SiN_n')
plt.legend()
plt.show()
plt.plot(wl, top_SiO2, label = 'top_SiO2')
plt.plot(wl, bot_SiO2, label = 'bot_SiO2')
plt.legend()
plt.show()
plt.plot(wl, SiO2_n, label = 'SiO2_n')
plt.legend()
plt.show()
plt.plot(wl, ITO, label = 'ITO')
plt.legend()
plt.show()
plt.plot(wl, ITO_n, label = 'ITO_n')
plt.legend()
plt.show()
