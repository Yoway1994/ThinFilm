# %%
import pandas as pd
import numpy as np
import material as ml
import matplotlib.pyplot as plt

# %%
oc = ml.open_material('OC', 'Sellmeier')
Acrylic = ml.open_material('Acrylic', 'Sellmeier')
OC_HRI_LENS = ml.open_material('OC_HRI_LENS', 'Material')
OC_LENS = ml.open_material('OC_LENS', 'Material')

# %%
x = np.linspace(400, 700)
wl = np.array(wl)
plt.plot(wl, oc.nvalues(wl), label = 'SemiLab_bridge')
plt.plot(wl, Acrylic.nvalues(wl), label = 'SemeLab_top OC')
plt.plot(wl, OC_LENS.nvalues(wl), label = 'LENS')
plt.legend(loc = 'best')
plt.show()
plt.plot(x, oc.kvalues(x))
plt.plot(x, Acrylic.kvalues(x))
plt.plot(x, OC_LENS.kvalues(x))
plt.xlim(400, 700)
plt.ylim(-0.001, 0.01)
plt.show()
