# %%
import numpy as np
import pandas as pd
import material as ml
import matplotlib.pyplot as plt

wl = np.linspace(400,700,301)
SG = pd.read_csv('./spectrum//Nanya/glass/Nanya_SG_R_5_B.csv')['SCAN'].values
SL = pd.read_csv('./spectrum//Nanya/glass/Nanya_soda_R_5_B.csv')['SCAN'].values

glass = ml.open_material('sodalime_Nanya','Material')
n = glass.nvalues(wl)
plt.plot(wl, n)
R = (1-n)**2/(1+n)**2
plt.show()
plt.plot(wl, 100*R)
plt.plot(wl, SG)
plt.plot(wl, SL)
plt.show()
