# %%
import numpy as np
import pandas as pd
import thinfilm as tm
import material as ml
import matplotlib.pyplot as plt

air = ml.Non_Dispersion(1)
sodalime = ml.open_material('sodalime', 'Material')
SiO2 = ml.open_material('SiO2_LENS', 'Sellmeier')
SiN = ml.open_material('SiN_LENS', 'Sellmeier')
ITO = ml.open_material('ITO_LENS', 'Sellmeier')
HOC = ml.open_material('OC_HRI_LENS', 'Material')
OC = ml.open_material('OC_LENS', 'Material')

wl = np.linspace(400, 700, 301)

hypo_bri = lambda th: tm.Design(
    [air,  SiN,SiO2, HOC, ITO, OC, ITO, SiO2, SiN, sodalime],
    [None, th[0], th[1], th[2]-1200, th[3], 1200, 20, th[4], th[5], None]
).reflectance(wl)

hypo_dia = lambda th: tm.Design(
    [air,  SiN, SiO2,HOC, ITO, SiO2, SiN, sodalime],
    [None, th[0], th[1], th[2], th[3], th[4], th[5], None]
).reflectance(wl)

hypo_tra = lambda th: tm.Design(
    [air,   SiN, SiO2,HOC,SiO2, SiN, sodalime],
    [None, th[0], th[1], th[2], th[4], th[5], None]
).reflectance(wl)

# %%
f3 = [27.89982662,9.77523851,1827.14970389,28.03156369,35.43383414,8.20002513]
f4 = [0,0,1827.14970389,28.03156369,35.43383414,8.20002513]
f5 = [0,0,0,28.03156369,35.43383414,8.20002513]

# %%
tk3 = f3
tk = f4
tk5 = f5
#plt.plot(wl, 100*hypo_bri(tk), '-r', label = 'bridge')
plt.plot(wl, 100*hypo_dia(tk3), '--k', label = 'XY-ITO')
plt.plot(wl, 100*hypo_tra(tk3), '--b', label = 'trace pattern')
plt.plot(wl, 100*hypo_dia(tk), '-k', label = 'XY-ITO')
plt.plot(wl, 100*hypo_tra(tk), '-b', label = 'trace pattern')
plt.plot(wl, 100*hypo_dia(tk5), '-k', label = 'XY-ITO')
plt.plot(wl, 100*hypo_tra(tk5), '-b', label = 'trace pattern')
plt.xlabel('wavelength(nm)', fontsize = 14)
plt.ylabel('R%', fontsize = 14)
plt.legend(loc = 'best')
#plt.savefig('LENS_rev2_simulation')
plt.show()

print('bridge:',100*np.mean(hypo_bri(tk)))
print('xy-ITO:',100*np.mean(hypo_dia(tk)))
print('pattern:',100*np.mean(hypo_tra(tk)))
print('delta_d_t:',np.mean(abs(100*hypo_tra(tk)-100*hypo_dia(tk))))
print('delta_d_b:',np.mean(abs(100*hypo_bri(tk)-100*hypo_dia(tk))))

plt.plot(100*hypo_bri(tk)-100*hypo_dia(tk))
plt.plot(100*hypo_tra(tk)-100*hypo_dia(tk))
plt.show()
# Out:
# bridge: 6.789353604712571
# xy-ITO: 5.88668827101688
# pattern: 5.577207237475542
# delta_d_t: 1.55276386952854
# delta_d_b: 2.4148782949657783

# %%
plt.plot(wl, 100*hypo_bri(tk), '-r', label = 'bridge')
plt.plot(wl, 100*hypo_dia(tk), '-k', label = 'XY-ITO')
plt.show()
plt.plot(wl, 100*hypo_bri(tk)-100*hypo_dia(tk))
plt.show()

# %%
plt.plot(wl, 100*hypo_bri(tk3), '-r', label = 'bridge')
plt.plot(wl, 100*hypo_dia(tk3), '-k', label = 'XY-ITO')
plt.show()
plt.plot(wl, 100*hypo_bri(tk3)-100*hypo_dia(tk3))
plt.show()

# %%
hypo_bri2 = lambda th: tm.Design(
    [air,  SiN,SiO2, HOC, ITO, OC, ITO, SiO2, SiN, sodalime],
    [None, th[0], th[1], th[2], th[3], 1200, 20, th[4], th[5], None]
).reflectance(wl)

plt.plot(wl, 100*hypo_bri2(tk5), '-r', label = 'bridge')
plt.plot(wl, 100*hypo_dia(tk5), '-k', label = 'XY-ITO')
plt.show()
plt.plot(wl, 100*hypo_bri2(tk5)-100*hypo_dia(tk5))
plt.show()
