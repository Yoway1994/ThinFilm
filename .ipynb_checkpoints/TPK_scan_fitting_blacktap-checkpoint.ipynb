# %%
import numpy as np
import pandas as pd
import material as ml
import thinfilm as tm
import matplotlib.pyplot as plt
from scipy.optimize import differential_evolution

wl = np.linspace(380, 780, 401)
R05 = pd.read_csv('./spectrum/TPK/R_5_B.csv')['SCAN'].values

air = ml.Non_Dispersion(1)
sub = ml.Non_Dispersion(1.52)
def hypo(th):
    SiON_L = ml.Chromatic_Dispersion(th[6], th[7], 550)
    SiON_H = ml.Chromatic_Dispersion(th[8], th[9], 550)
    ITO = ml.Chromatic_Dispersion(th[10], th[11], 550)
    Arc = ml.Chromatic_Dispersion(th[12], th[13], 550)
    hypo_R = tm.Design(
        [air, Arc, SiON_H, SiON_L, ITO, SiON_L, SiON_H, sub],
        [None, th[0], th[1], th[2], th[3], th[4], th[5], None]
    )
    RRR = hypo_R.reflectance(wl, 5)
    return RRR

def hypo_tra(th):
    SiON_L = ml.Chromatic_Dispersion(th[6], th[7], 550)
    SiON_H = ml.Chromatic_Dispersion(th[8], th[9], 550)
    Arc = ml.Chromatic_Dispersion(th[12], th[13], 550)
    hypo_R = tm.Design(
        [air, Arc, SiON_H, SiON_L, SiON_L, SiON_H, sub],
        [None, th[0], th[1], th[2], th[4], th[5], None]
    )
    RRR = hypo_R.reflectance(wl, 5)
    return RRR

fom = lambda th: tm.RMSE(100*hypo(th),R05)

# %% [markdown]
#  None, 1250, 24.25, 17.81, 46.64, 16.11, 24.59, None

# %%
sol = differential_evolution(
    fom, [
        (900,1300),
        (20.24,28.25),
        (13.81,22.81),
        (42.64,50.64),
        (12.11,20.11),
        (20.59,28.59),
        (1.44,1.55), (-1,0),
        (1.7,2.1), (-1,0),
        (1.6,1.9), (-1,0),
        (1.48,1.55), (-1,0),
    ], disp=True, polish=False, popsize=20, mutation=0.3, recombination =0.9,strategy = 'best1exp'
)
print(sol.x)
# Out:
# differential_evolution step 1: f(x)= 1.41264
# differential_evolution step 2: f(x)= 1.14983
# differential_evolution step 3: f(x)= 1.13218
# differential_evolution step 4: f(x)= 0.876149
# differential_evolution step 5: f(x)= 0.731243
# differential_evolution step 6: f(x)= 0.626763
# differential_evolution step 7: f(x)= 0.564688
# differential_evolution step 8: f(x)= 0.522697
# differential_evolution step 9: f(x)= 0.519136
# differential_evolution step 10: f(x)= 0.451041
# differential_evolution step 11: f(x)= 0.427851
# differential_evolution step 12: f(x)= 0.427851
# differential_evolution step 13: f(x)= 0.379036
# differential_evolution step 14: f(x)= 0.373464
# differential_evolution step 15: f(x)= 0.358105
# differential_evolution step 16: f(x)= 0.32845
# differential_evolution step 17: f(x)= 0.32845
# differential_evolution step 18: f(x)= 0.314131
# differential_evolution step 19: f(x)= 0.295236
# differential_evolution step 20: f(x)= 0.278596
# differential_evolution step 21: f(x)= 0.278596
# differential_evolution step 22: f(x)= 0.276604
# differential_evolution step 23: f(x)= 0.276604
# differential_evolution step 24: f(x)= 0.276522
# differential_evolution step 25: f(x)= 0.276522
# differential_evolution step 26: f(x)= 0.274888
# differential_evolution step 27: f(x)= 0.274888
# differential_evolution step 28: f(x)= 0.274888
# differential_evolution step 29: f(x)= 0.274043
# differential_evolution step 30: f(x)= 0.273467
# differential_evolution step 31: f(x)= 0.273467
# differential_evolution step 32: f(x)= 0.268987
# differential_evolution step 33: f(x)= 0.268987
# differential_evolution step 34: f(x)= 0.265921
# differential_evolution step 35: f(x)= 0.264193
# differential_evolution step 36: f(x)= 0.260136
# differential_evolution step 37: f(x)= 0.258273
# differential_evolution step 38: f(x)= 0.253342
# differential_evolution step 39: f(x)= 0.250919
# differential_evolution step 40: f(x)= 0.249885
# differential_evolution step 41: f(x)= 0.245183
# differential_evolution step 42: f(x)= 0.245183
# differential_evolution step 43: f(x)= 0.24405
# differential_evolution step 44: f(x)= 0.241604
# differential_evolution step 45: f(x)= 0.24155
# differential_evolution step 46: f(x)= 0.240898
# differential_evolution step 47: f(x)= 0.240616
# differential_evolution step 48: f(x)= 0.240445
# differential_evolution step 49: f(x)= 0.240445
# differential_evolution step 50: f(x)= 0.240445
# differential_evolution step 51: f(x)= 0.240445
# differential_evolution step 52: f(x)= 0.240159
# differential_evolution step 53: f(x)= 0.240159
# differential_evolution step 54: f(x)= 0.240159
# differential_evolution step 55: f(x)= 0.240159
# differential_evolution step 56: f(x)= 0.240159
# differential_evolution step 57: f(x)= 0.240159
# differential_evolution step 58: f(x)= 0.240159
# differential_evolution step 59: f(x)= 0.240068
# differential_evolution step 60: f(x)= 0.239359
# differential_evolution step 61: f(x)= 0.239359
# differential_evolution step 62: f(x)= 0.239359
# differential_evolution step 63: f(x)= 0.239209
# differential_evolution step 64: f(x)= 0.239209
# differential_evolution step 65: f(x)= 0.239209
# differential_evolution step 66: f(x)= 0.239209
# differential_evolution step 67: f(x)= 0.239209
# differential_evolution step 68: f(x)= 0.239209
# differential_evolution step 69: f(x)= 0.239209
# differential_evolution step 70: f(x)= 0.239167
# differential_evolution step 71: f(x)= 0.239074
# differential_evolution step 72: f(x)= 0.239001
# differential_evolution step 73: f(x)= 0.238971
# differential_evolution step 74: f(x)= 0.238969
# differential_evolution step 75: f(x)= 0.238964
# differential_evolution step 76: f(x)= 0.23886
# differential_evolution step 77: f(x)= 0.238834
# [ 9.51947094e+02  2.82486970e+01  2.28005594e+01  5.06274016e+01
#   2.01039707e+01  2.19036286e+01  1.44167869e+00 -2.72081849e-05
#   1.78131747e+00 -3.31244714e-05  1.60769745e+00 -8.21466725e-01
#   1.51985969e+00 -7.38408487e-05]

# %%
m1 = [
    9.51947094e+02,
    2.82486970e+01,
    2.28005594e+01,
    5.06274016e+01,
    2.01039707e+01,
    2.19036286e+01,
    1.44167869e+00,-2.72081849e-05,
    1.78131747e+00,-3.31244714e-05,
    1.60769745e+00,-8.21466725e-01,
    1.51985969e+00,-7.38408487e-05
]
tk = m1

plt.plot(wl, 100*hypo(tk),'-k', label = 'fitting')
plt.plot(wl, R05, 'ks', label = 'SCAN', markersize = 1)
plt.xlabel('wavelength(nm)', fontsize = 14)
plt.ylabel('R%', fontsize = 14)
plt.legend(loc = 'best')
#plt.savefig('TPK_R_5_B.png')
plt.show()
plt.plot(wl, 100*hypo(tk),'-k', label = 'XY-ITO')
plt.plot(wl, 100*hypo_tra(tk),'-b', label = 'trace pattern')
plt.legend(loc = 'best')
plt.xlabel('wavelength(nm)', fontsize = 14)
plt.ylabel('R%', fontsize = 14)
plt.savefig('TPK_delta_d_t.png')
plt.show()
print('xy-ITO:',np.mean(100*hypo(tk)))
print('trace pattern:',np.mean(100*hypo_tra(tk)))
print('delta_d_t:', np.mean(100*abs(hypo(tk)-hypo_tra(tk))))
# Out:
# xy-ITO: 4.412166579923132
# trace pattern: 4.576608005563116
# delta_d_t: 1.36721368027251

# %%
xSiON_L = ml.Chromatic_Dispersion(tk[6], tk[7], 550)
xSiON_H = ml.Chromatic_Dispersion(tk[8], tk[9], 550)
xITO = ml.Chromatic_Dispersion(tk[10], tk[11], 550)
xArc = ml.Chromatic_Dispersion(tk[12], tk[13], 550)

plt.plot(wl, xSiON_L.nvalues(wl))
plt.plot(wl, xSiON_H.nvalues(wl))
plt.plot(wl, xITO.nvalues(wl))
plt.plot(wl, xArc.nvalues(wl))
plt.show()
print(xArc.nvalues(550))
# Out:
# 1.5198596911553592
