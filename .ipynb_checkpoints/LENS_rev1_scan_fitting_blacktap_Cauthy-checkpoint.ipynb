# %%
import numpy as np
import pandas as pd
import material as ml
import thinfilm as tm
import matplotlib.pyplot as plt
from scipy.optimize import differential_evolution, minimize

wl = np.linspace(400, 700, 301)
R_scan = pd.read_csv('./spectrum/LENS/rev1/R_5_B.csv')['SCAN'].values

air = ml.Non_Dispersion(1)
ITO_L = ml.open_material('ITO_LENS', 'Sellmeier') 
SiO2_L = ml.open_material('SiO2_LENS', 'Sellmeier') 
SiN_L = ml.open_material('SiN_LENS', 'Sellmeier')
OC = ml.open_material('OC_LENS', 'Material')
sodalime = ml.open_material('sodalime', 'Material')
ITO = ml.Cauchy([1.640727, 0.050604], ITO_L.k, ITO_L.wl_k)
SiN = ml.Cauchy([1.97812451, 0.0100578])
SiO2 = ml.Cauchy([1.50818418, 0.00141496727])
                
R_hypo = lambda th: tm.Design(
    [air, OC, SiN, SiO2, ITO, SiO2, SiN, sodalime],
    [None, th[0], th[1], th[2], th[3], th[4], th[5], None]
).reflectance(wl, 5)

R_hypo_tra = lambda th: tm.Design(
    [air, OC, SiN, SiO2, SiO2, SiN, sodalime],
    [None, th[0], th[1], th[2], th[4], th[5], None]
).reflectance(wl, 5)


SEM = lambda th: abs(th[1]+th[2]-52.5)+abs(th[4]+th[5]-53.6)
IM =lambda th: sum(abs(R_hypo(th)-R_hypo_tra(th)))
FOM = lambda th: 10*np.mean(abs(100*R_hypo(th)-R_scan)) + SEM(th)

# %%
sol = differential_evolution(
    FOM, [
        (1500,2000), # O.C
        (5,20), # T SiN
        (30,55), # T SiO2
        (26,30), # ITO
        (30,55), # B SiN
        (5,20), # B SiO2
    ], disp = True, polish = False, popsize = 15, mutation = 0.3, recombination = 0.9, strategy = 'rand1exp'
)
print(sol.x)
# Out:
# differential_evolution step 1: f(x)= 8.24966
# differential_evolution step 2: f(x)= 8.24966
# differential_evolution step 3: f(x)= 8.24966
# differential_evolution step 4: f(x)= 5.82887
# differential_evolution step 5: f(x)= 5.82887
# differential_evolution step 6: f(x)= 5.82887
# differential_evolution step 7: f(x)= 5.82887
# differential_evolution step 8: f(x)= 5.82887
# differential_evolution step 9: f(x)= 5.82887
# differential_evolution step 10: f(x)= 5.77909
# differential_evolution step 11: f(x)= 5.77909
# differential_evolution step 12: f(x)= 5.77909
# differential_evolution step 13: f(x)= 5.77909
# differential_evolution step 14: f(x)= 4.70095
# differential_evolution step 15: f(x)= 4.18449
# differential_evolution step 16: f(x)= 4.03809
# differential_evolution step 17: f(x)= 4.03809
# differential_evolution step 18: f(x)= 4.03809
# differential_evolution step 19: f(x)= 3.90744
# differential_evolution step 20: f(x)= 3.90744
# differential_evolution step 21: f(x)= 3.85971
# differential_evolution step 22: f(x)= 3.339
# differential_evolution step 23: f(x)= 3.339
# differential_evolution step 24: f(x)= 3.339
# differential_evolution step 25: f(x)= 3.339
# differential_evolution step 26: f(x)= 3.23919
# differential_evolution step 27: f(x)= 3.10297
# differential_evolution step 28: f(x)= 3.10297
# differential_evolution step 29: f(x)= 3.10297
# differential_evolution step 30: f(x)= 3.06514
# differential_evolution step 31: f(x)= 3.06514
# differential_evolution step 32: f(x)= 3.06514
# differential_evolution step 33: f(x)= 3.06126
# differential_evolution step 34: f(x)= 3.04655
# differential_evolution step 35: f(x)= 2.98569
# differential_evolution step 36: f(x)= 2.96566
# differential_evolution step 37: f(x)= 2.95999
# differential_evolution step 38: f(x)= 2.94256
# differential_evolution step 39: f(x)= 2.92588
# differential_evolution step 40: f(x)= 2.92588
# differential_evolution step 41: f(x)= 2.92588
# differential_evolution step 42: f(x)= 2.90199
# differential_evolution step 43: f(x)= 2.90199
# differential_evolution step 44: f(x)= 2.89968
# differential_evolution step 45: f(x)= 2.89968
# differential_evolution step 46: f(x)= 2.89968
# differential_evolution step 47: f(x)= 2.89563
# differential_evolution step 48: f(x)= 2.87859
# differential_evolution step 49: f(x)= 2.87859
# [1728.01115927   14.3870235    38.11820806   29.69018659   46.6469324
#     6.95233569]

# %%
plt.plot(wl, 100*R_hypo(sol.x))
plt.plot(wl, R_scan)
#plt.plot(wl, 100*R_hypo_tra(sol.x))
plt.show()

# %%
plt.plot(wl, ITO.nvalues(wl))
plt.plot(wl, ITO_L.nvalues(wl))
plt.show()
plt.plot(wl, SiN.nvalues(wl))
plt.plot(wl, SiN_L.nvalues(wl))
plt.show()
plt.plot(wl, SiO2.nvalues(wl))
plt.plot(wl, SiO2_L.nvalues(wl))
plt.show()
